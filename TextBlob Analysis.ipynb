# %%
import csv

# %%
from textblob import TextBlob

# %%
myfile = '/home/myspark/tweet_data2.csv'

# %%
with open(myfile, 'r') as csvfile:
    rows = csv.reader(csvfile)
    for row in rows:
        sentence = row[0]
        blob = TextBlob(sentence)
        print (sentence)
        print (blob.sentiment.polarity, blob.sentiment.subjectivity)
# Out:
#  Im_TheAntiTrump: Trump's 1st rape charge was y ex-wife Ivana &amp; was settled as part of the divorce settlement.
# 0.0 0.0
#  Im_TheAntiTrump: #TrumpPedoGate #TrumpRape
# 0.0 0.0
#  AG_Conservative: Straight
# 0.2 0.4
#  piersmorgan: Today, jk_rowling posted 8 hateful tweets aout Donald Trump 'snuing' a disaled oy.
# 0.0 0.0
#  richarddeitsch: I elieve this more today than I did on Nov. 7.
# 0.5 0.5
# Donald J. Trump on Twitter
# 0.0 0.0
#  Newsweek: Donald Trump
# 0.0 0.0
#  Impeach_D_Trump: Donald Trump is a weak person
# -0.375 0.625
#  TheScotsman: Piers Morgan calls JK Rowling
# 0.0 0.0
# The KevinNR piece on realDonaldTrump is the king of dressings down. It's drop the mic, rap-attle savage. #fdt
# -0.15555555555555559 0.2888888888888889
# Donald Trump Has Parted Ways With A Shocking Numer Of Senior Officials - HuffPost
# -1.0 1.0
#  NancySinatra: 35 psychiatrists just met at Yale to warn Donald Trump has a 'dangerous mental illness'
# -0.35 0.55
# ...
